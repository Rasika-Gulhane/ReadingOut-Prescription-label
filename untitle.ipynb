# %%
import os

# %%
from PIL import Image
import pytesseract

# %%
import cv2
# from google.colab.patches import cv2_imshow

# %%
pytesseract.pytesseract.tesseract_cmd = r'/content/tesseract-ocr-w64-setup-5.3.3.20231005.exe'

# %%
import os

# %%
api_key = os.environ.get('MONGO_DB_URL')

# %%
print(f"API Key: {api_key}")
# Out:
# API Key: None

# %%
secret_key = os.environ.get('AWS_SECRET_ACESS_KEY')

# %%
print(f"Secret Key: {secret_key}")
# Out:
# Secret Key: aws_secret_key
